# %%
import pandas as pd

# %%
file_path = r"E:\문화빅데이터플랫폼\JT_SNS_KWRD_LIST\JT_SNS_KWRD_LIST"
JT_SNS_KWRD_LIST = pd.read_csv(file_path)

JT_SNS_KWRD_LIST
# Out:
#        SRCHWRD_NM ORIGIN_CL_NM ALL_KWRD_CN  ALL_KWRD_CO  \
# 0           981파크        네이버카페         NaN            0
# 1             산방산        네이버카페         NaN            0
# 2             산방산        네이버카페         NaN            0
# 3             산방산        네이버카페         NaN            0
# 4             산방산        네이버카페         NaN            0
# ...           ...          ...         ...          ...
# 666853       제주여행          트위터        제주여행            1
# 666854       제주여행          트위터        제주여행            1
# 666855       제주여행          트위터        제주여행            1
# 666856       제주여행          트위터        제주여행            1
# 666857       제주여행          트위터        제주여행            1
#
#                                                  ORGT_URL  \
# 0       https://cafe.naver.com/sungdeokpress/862?art=Z...
# 1       https://cafe.naver.com/jejuhee/58681?art=ZXh0Z...
# 2       https://cafe.naver.com/jejutip/2362416?art=ZXh...
# ...

# %%
cl_nm_uni = JT_SNS_KWRD_LIST['SRCHWRD_NM'].unique()
cl_nm_uni
# Out:
# array(['981파크', '산방산', '제주관광', '제주여행', '천제연폭포', '카멜리아힐', '성산일출봉', '비자림',
#        '스누피가든', '용머리해안', '제주가볼만한곳', '새별오름', '제주도여행', '제주맛집', '금오름',
#        '궷물오름', '따라비오름', '천지연폭포', '메이즈랜드', '빛의벙커', '여미지식물원', '제주도가볼만한곳',
#        '제주도맛집', '제주도카페', '제주도캠핑', '제주카페', '제주캠핑', '제주도관광', '제주도차박',
#        '제주차박', '테디베어뮤지엄제주', '제주실탄사격장'], dtype=object)

# %%
JT_SNS_KWRD_LIST.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 666858 entries, 0 to 666857
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   SRCHWRD_NM    666858 non-null  object
#  1   ORIGIN_CL_NM  666858 non-null  object
#  2   ALL_KWRD_CN   627439 non-null  object
#  3   ALL_KWRD_CO   666858 non-null  int64
#  4   ORGT_URL      666858 non-null  object
#  5   NTCE_CN       649872 non-null  object
#  6   COMMENT_CO    666858 non-null  int64
#  7   NTCE_DE       666858 non-null  int64
#  8   COLCT_DE      666858 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 45.8+ MB

# %%
JT_SNS_KWRD_LIST = JT_SNS_KWRD_LIST.drop(JT_SNS_KWRD_LIST[['ORIGIN_CL_NM', '']])
